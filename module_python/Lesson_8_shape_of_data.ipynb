# %%
import pandas as pd

# %% [markdown]
# stack(), unstack()

# %%
pokemon = pd.read_csv('C:/Users/1/JupyterProjects/Karpov_curses_lessons_and_projects/module_python/all_data/Pokemon.csv')

# %%
pokemon
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander     Fire     NaN    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
# ...

# %%
pokemon.rename(columns=lambda x: x.lower().replace(' ', '_').replace('.', ''), inplace=True)

# %%
pokemon.rename(columns={'#': 'id'}, inplace=True)

# %%
pokemon
# Out:
#       id                   name   type_1  type_2  total  hp  attack  defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander     Fire     NaN    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
# ...

# %%
legends = pokemon.groupby('generation').agg({'legendary': 'value_counts'}).rename(columns={'legendary': 'count'})

# %%
legends = legends.unstack(level='legendary')

# %%
legends
# Out:
#            count
# legendary  False True
# generation
# 1            160    6
# 2            101    5
# 3            142   18
# 4            108   13
# 5            150   15
# 6             74    8

# %%
pokemon.query('legendary == True')\
        .groupby(['generation', 'type_1'])\
        .agg({'legendary': 'count'})\
        .rename(columns={'legendary': 'legendary_count'})\
        .sort_values('legendary_count', ascending=False)
# Out:
#                      legendary_count
# generation type_1
# 3          Dragon                  6
# 5          Dragon                  5
# 3          Psychic                 4
# 1          Psychic                 3
# 4          Psychic                 3
#            Grass                   2
# 3          Water                   2
# 6          Psychic                 2
# 5          Ground                  2
#            Flying                  2
#            Electric                2
# 4          Normal                  2
#            Ghost                   2
# 6          Rock                    2
# 3          Steel                   2
#            Ground                  2
# 2          Fire                    2
# 3          Rock                    1
# 1          Fire                    1
#            Ice                     1
# 6          Fire                    1
#            Fairy                   1
#            Dragon                  1
#            Dark                    1
# ...

# %% [markdown]
# melt(), wide_to_long()

# %%
avocado_agg = pd.DataFrame({'type' : ['conventional', 'organic'],
                            'AvgPrice_2015' : [1.077963, 1.673324],
                            'AvgPrice_2016' : [1.105595, 1.571684],
                            'AvgPrice_2017' : [1.294888, 1.735521],
                            'AvgPrice_2018' : [1.127886, 1.567176],
                            })
avocado_agg
# Out:
#            type  AvgPrice_2015  AvgPrice_2016  AvgPrice_2017  AvgPrice_2018
# 0  conventional       1.077963       1.105595       1.294888       1.127886
# 1       organic       1.673324       1.571684       1.735521       1.567176

# %%
avocado_agg_long = pd.wide_to_long(avocado_agg, stubnames=['AvgPrice'], i=['type'], j='year', sep='_')

# %%
avocado_agg_long
# Out:
#                    AvgPrice
# type         year
# conventional 2015  1.077963
# organic      2015  1.673324
# conventional 2016  1.105595
# organic      2016  1.571684
# conventional 2017  1.294888
# organic      2017  1.735521
# conventional 2018  1.127886
# organic      2018  1.567176

# %%
superheroes = pd.read_csv('C:/Users/1/JupyterProjects/Karpov_curses_lessons_and_projects/module_python/all_data/superheroes_power_matrix.csv')

# %%
superheroes
# Out:
#                 Name  Agility  Accelerated Healing  Lantern Power Ring  \
# 0            3-D Man     True                False               False
# 1             A-Bomb    False                 True               False
# 2         Abe Sapien     True                 True               False
# 3           Abin Sur    False                False                True
# 4        Abomination    False                 True               False
# ..               ...      ...                  ...                 ...
# 662  Yellowjacket II    False                False               False
# 663             Ymir    False                False               False
# 664             Yoda     True                False               False
# 665          Zatanna    False                False               False
# 666             Zoom    False                False               False
#
#      Dimensional Awareness  Cold Resistance  Durability  Stealth  \
# ...

# %%
superheroes_long = superheroes.melt(id_vars='Name', var_name='superpower')

# %%
superheroes_powers = superheroes_long.query('value == True')\
        .groupby('Name')\
        .superpower.apply(list)\
        .to_frame().reset_index()

# %%
superheroes_powers
# Out:
#                 Name                                         superpower
# 0            3-D Man    [Agility, Super Strength, Stamina, Super Speed]
# 1             A-Bomb  [Accelerated Healing, Durability, Longevity, S...
# 2         Abe Sapien  [Agility, Accelerated Healing, Cold Resistance...
# 3           Abin Sur                               [Lantern Power Ring]
# 4        Abomination  [Accelerated Healing, Intelligence, Super Stre...
# ..               ...                                                ...
# 662  Yellowjacket II             [Flight, Energy Blasts, Size Changing]
# 663             Ymir  [Cold Resistance, Durability, Longevity, Super...
# 664             Yoda  [Agility, Stealth, Danger Sense, Marksmanship,...
# 665          Zatanna  [Cryokinesis, Telepathy, Magic, Fire Control, ...
# 666             Zoom  [Super Speed, Intangibility, Time Travel, Time...
#
# [667 rows x 2 columns]

# %%
superheroes_powers_second = superheroes_long.query('value == True')\
        .groupby(['Name'], as_index=False)\
        .agg({'superpower':list})   # второй способ обернуть группировку в список

# %%
superheroes_powers_second.head()
# Out:
#           Name                                         superpower
# 0      3-D Man    [Agility, Super Strength, Stamina, Super Speed]
# 1       A-Bomb  [Accelerated Healing, Durability, Longevity, S...
# 2   Abe Sapien  [Agility, Accelerated Healing, Cold Resistance...
# 3     Abin Sur                               [Lantern Power Ring]
# 4  Abomination  [Accelerated Healing, Intelligence, Super Stre...

# %%
np.array_equal(superheroes_powers, superheroes_powers_second) # сравнение двух датафреймов
# Out:
# True
