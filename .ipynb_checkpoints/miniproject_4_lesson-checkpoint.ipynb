# %%
import os 
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import re

# %% [markdown]
# На этот раз данные имеют следующую структуру:
#
# записываются для каждого пользователя, совершившего покупки, каждый день
# для каждой даты есть своя папка, внутри неё – папки для каждого пользователя
# внутри каждой папки есть файл data.csv, где и хранятся данные

# %% [markdown]
# Собераем все данные из папки data в один датафрэйм, имеющий следующие столбцы: колонки из самих файлов (product_id, quantity), имя пользователя (name), и дату этих покупок (date), соответствует названию папки, где лежит папка с пользователем).

# %%
df = pd.DataFrame()

# %%
for date in os.listdir('C:/Users/1/JupyterProjects/Karpov_curses_lessons_and_projects/4_data/data/'):
    for name in os.listdir(f'C:/Users/1/JupyterProjects/Karpov_curses_lessons_and_projects/4_data/data/{date}'):
        result_data = pd.read_csv(f'C:/Users/1/JupyterProjects/Karpov_curses_lessons_and_projects/4_data/data/{date}/{name}/data.csv')
        result_data['name'] = name
        result_data['date'] = date
        df = pd.concat([df, result_data])

# %%
df = df.drop(columns=['Unnamed: 0'])

# %%
df = df.reset_index(drop=True)

# %%
df
# Out:
#      product_id  quantity              name        date
# 0            47         1    Alexey_Smirnov  2020-12-03
# 1            57         1    Alexey_Smirnov  2020-12-03
# 2            14         2    Alexey_Smirnov  2020-12-03
# 3            52         1    Alexey_Smirnov  2020-12-03
# 4             1         4    Alexey_Smirnov  2020-12-03
# ..          ...       ...               ...         ...
# 156          66         4  Rostislav_Petrov  2020-12-09
# 157          39         2  Rostislav_Petrov  2020-12-09
# 158          82         4    Vasiliy_Ivanov  2020-12-09
# 159          74         2    Vasiliy_Ivanov  2020-12-09
# 160          54         3    Vasiliy_Ivanov  2020-12-09
#
# [161 rows x 4 columns]

# %%
df.quantity.sum()
# Out:
# 480

# %% [markdown]
# Какие пользователи купили больше всего товаров?

# %%
max_quantity = df.groupby('name', as_index=False).agg({'quantity': 'sum'}).quantity.max()

# %%
df.groupby('name', as_index=False).agg({'quantity': 'sum'}).query('quantity == @max_quantity').name
# Out:
# 3     Alexey_Smirnov
# 13      Petr_Smirnov
# Name: name, dtype: object

# %% [markdown]
# Топ-10 товаров по числу проданных единиц за всё время и построение барплота

# %%
top_10 = df.groupby('product_id', as_index=False).agg({'quantity': 'sum'}).sort_values(by='quantity', ascending=False).iloc[:10]

# %%
sns.barplot(data=top_10, x='product_id', y='quantity', color='Red', alpha=0.5)
# Out:
# <AxesSubplot:xlabel='product_id', ylabel='quantity'>

# %% [markdown]
# Посмотрим на продажи по дням

# %%
quantity_per_date = df.groupby('date', as_index=False).agg({'quantity': 'sum'})

# %%
plt.figure(figsize=(10, 6))
sns.barplot(data=quantity_per_date, x='date', y='quantity', color='Red', alpha=0.5)
# Out:
# <AxesSubplot:xlabel='date', ylabel='quantity'>

# %% [markdown]
# Сколько пользователей приобрели какой-либо товар повторно (более 1 раза)? Повтором будем считать покупку товара с одинаковым product_id, совершенную в разные дни.

# %%
df_without_duplicates = df.drop_duplicates(subset=['name', 'product_id', 'date']) #убираем дубликаты по 3 параметрам

# %%
df_without_duplicates.loc[df_without_duplicates.duplicated(subset=['name', 'product_id'])] #находим дубликаты по 2 параметрам
# Out:
#      product_id  quantity          name        date
# 104          94         4  Petr_Fedorov  2020-12-07
# 147          15         3  Anton_Ivanov  2020-12-09

# %% [markdown]
# Дополнительное задание

# %%
# !pip install xlrd
# Out:
# ...
# WARNING: You are using pip version 21.2.3; however, version 22.3.1 is available.
# You should consider upgrading via the 'C:\Users\1\AppData\Local\Programs\Python\Python310\python.exe -m pip install --upgrade pip' command.

# %%
inn = pd.read_excel('C:/Users/1/JupyterProjects/Karpov_curses_lessons_and_projects/4_inn.xls')

# %%
inn
# Out:
#       Unnamed: 0     #                                    name     reg_number  \
# 0              0     0         ЗАО «Власова, Макаров и Шашков»  1143692580560
# 1              1     1  РАО «Тимофеева, Алексеева и Кузнецова»  9342309660697
# 2              2     2                      РАО «Юдин-Ефимова»  1277485323451
# 3              3     3                   Доронин Инкорпорэйтед  7139161431511
# 4              4     4    Объединенная энергетическая компания  6114798049639
# ...          ...   ...                                     ...            ...
# 2105        2105  2105         ИП «Зайцев, Шубин и Дементьева»  6580539599719
# 2106        2106  2106                               Юдина Лтд  5012825137426
# 2107        2107  2107                        Антонова Лимитед  7659150538516
# 2108        2108  2108                    ООО «Хохлов Казаков»  9506828156265
# 2109        2109  2109                  ИП «Кабанов Ситникова»  5283860848622
#
# ...

# %%
necessary_inn = []
with open('C:/Users/1/JupyterProjects/Karpov_curses_lessons_and_projects/4_necessary_inn.txt') as f:
    for line in f:
        line = re.split(r'\n', line)
        necessary_inn.append(line[0])

# %%
necessary_inn = pd.Series(necessary_inn)

# %%
necessary_inn = necessary_inn.astype('int64')

# %%
selected = inn.query('head_inn in @necessary_inn')

# %%
selected
# Out:
#       Unnamed: 0     #                                name     reg_number  \
# 47            47    47                      Пермэнергосбыт  6417532956774
# 76            76    76              ЗАО «Кабанова Ковалев»  9343329412518
# 77            77    77                             Неофарм  3813743111150
# 85            85    85                         Арконик СМЗ  7465966885549
# 90            90    90                     Фармперспектива  6205521489390
# ...          ...   ...                                 ...            ...
# 2059        2059  2059    ЗАО «Кабанова, Титов и Бирюкова»  4405157155853
# 2074        2074  2074  ООО «Фомин, Симонова и Никифорова»  9213736030860
# 2089        2089  2089                  НПО «Зимин Иванов»  6791957421599
# 2106        2106  2106                           Юдина Лтд  5012825137426
# 2108        2108  2108                ООО «Хохлов Казаков»  9506828156265
#
#                                                 address  \
# ...

# %%
selected = selected.drop(columns=['Unnamed: 0', '#'])

# %%
selected.reset_index(drop=True)
# Out:
#                                    name     reg_number  \
# 0                        Пермэнергосбыт  6417532956774
# 1                ЗАО «Кабанова Ковалев»  9343329412518
# 2                               Неофарм  3813743111150
# 3                           Арконик СМЗ  7465966885549
# 4                       Фармперспектива  6205521489390
# ..                                  ...            ...
# 110    ЗАО «Кабанова, Титов и Бирюкова»  4405157155853
# 111  ООО «Фомин, Симонова и Никифорова»  9213736030860
# 112                  НПО «Зимин Иванов»  6791957421599
# 113                           Юдина Лтд  5012825137426
# 114                ООО «Хохлов Казаков»  9506828156265
#
#                                                address  \
# 0    ст. Слюдянка, пер. Брянский, д. 378 стр. 634, ...
# 1       с. Нарткала, ул. Верхняя, д. 68 стр. 1, 393309
# 2        г. Долинск, ш. Московское, д. 25 к. 5, 227970
# 3     п. Тобольск, ул. Лунная, д. 375 стр. 724, 119588
# ...

# %%
selected.to_csv('selected_inn.csv')

# %%
selected['income,RUB'].sum()
# Out:
# 6104522627393
